# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Question 1

# %%
st = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age', 'Nationality','Overall']

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age','Nationality','Overall']

# %%
pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
pd.DataFrame(lst, columns = col, index = [1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [markdown]
# # Question 2

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin1')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
madagascar = df[df['Area']=='Madagascar']
madagascar[madagascar['Element']=='Protein supply quantity (g/capita/day)']['Y2015'].sum()
# Out:
# 173.04999999999998

# %% [markdown]
# # Question 3

# %%
array  = np.array([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
array[:2,1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %% [markdown]
# # Question 4

# %%
df['Y2017'].mean()
# Out:
# 140.917764860268

# %%
df['Y2017'].std()
# Out:
# 1671.8623590572788

# %% [markdown]
# # Question 5

# %%
# Dictionary and Set are unorderly data structures

# %% [markdown]
# # Question 6

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %% [markdown]
# # Question 7

# %%
# df.iloc() could be used to access elements across rows and columns

# %% [markdown]
# # Question 8

# %%
grouped_sum = df.groupby('Element').sum()
grouped_sum
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
grouped_sum.at['Processing', 'Y2017']
# Out:
# 292836.0

# %% [markdown]
# # Question 9

# %%
grouped_item_sum = df.groupby('Item').sum()
grouped_item_sum
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
grouped_item_sum.at['Wine', 'Y2015']
# Out:
# 4251.81

# %%
grouped_item_sum.at['Wine', 'Y2018']
# Out:
# 4039.32

# %% [markdown]
# # Question 10

# %%
len(df)
# Out:
# 60943

# %%
df.shape # has the number of rows and columns
# Out:
# (60943, 12)

# %% [markdown]
# # Question 11

# %%
df[['Y2017', 'Area']].groupby('Area').sum().sort_values(by='Y2017', ascending=False)
# Out:
#                                   Y2017
# Area
# Nigeria                      1483268.23
# Egypt                         866379.92
# South Africa                  517590.54
# Ethiopia                      448683.76
# Morocco                       388495.36
# Ghana                         337599.06
# Algeria                       325644.27
# United Republic of Tanzania   322616.85
# Kenya                         264660.66
# Sudan                         239931.92
# Cameroon                      232030.43
# Angola                        229159.57
# Côte d'Ivoire                 224599.01
# Uganda                        213950.38
# Malawi                        181098.71
# Mozambique                    161407.98
# Mauritania                    156665.46
# Mali                          149928.33
# Madagascar                    131197.73
# Niger                         126707.58
# Benin                         124771.22
# Tunisia                       124167.20
# ...

# %% [markdown]
# # Question 12

# %%
grouped_by_element = df.groupby('Element').sum()
grouped_by_element
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
all_years = grouped_by_element.loc['Stock Variation'][['Y2014', 'Y2015','Y2016','Y2017', 'Y2018']]
all_years
# Out:
# Y2014    58749.83
# Y2015    34910.99
# Y2016    33140.12
# Y2017    54316.91
# Y2018    20577.91
# Name: Stock Variation, dtype: float64

# %%
all_years.idxmax()
# Out:
# 'Y2014'

# %%
df[['Y2017', 'Area']].groupby('Area').sum().sort_values(by='Y2017', ascending=True)
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %%
len(df['Area'].unique())
# Out:
# 49

# %%
df.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
Given the following python code, what would the output of the code give?

my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# Object `give` not found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-4cfc7aadf937> in <module>
#       3 my_tuppy = (1,2,5,8)
#       4
# ----> 5 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

# %%
y[1][-1]
# Out:
# 8

# %%
y[1][1]
# Out:
# 8

# %%
df.corr()['Element Code']
# Out:
# Area Code      -0.000209
# Item Code      -0.024683
# Element Code    1.000000
# Y2014           0.024457
# Y2015           0.023889
# Y2016           0.023444
# Y2017           0.024254
# Y2018           0.024279
# Name: Element Code, dtype: float64
